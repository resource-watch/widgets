# %% [markdown]
# ### Data
# com.009 Material Extraction, Trade, and Use 3 <br>
# https://resourcewatch.carto.com/u/wri-rw/dataset/com_009_flowmfa_autoupdate <br>

# %%
import numpy as np
import vega
import json
from vega import Vega

# %% [markdown]
# ### Resource Watch specification
# API ID: 130c75f9-5256-4150-8329-1ef59c6d2c46 <br>
# https://resourcewatch.org/embed/widget/130c75f9-5256-4150-8329-1ef59c6d2c46

# %%
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/909ad4e2-51d6-4c57-b498-79af37a59bb2?sql=SELECT mfa4, CASE WHEN mfa4='BM' THEN 'Biomass' WHEN mfa4='FF' THEN 'Fossil Fuels' WHEN mfa4='MO' THEN 'Metal Ores' WHEN mfa4='NM' THEN 'Non-Metallic Minerals' END AS c, year AS x, SUM(amount)*1000 as y FROM com_009_flowmfa_autoupdate WHERE flow ILIKE 'DMC' GROUP BY mfa4, year ORDER BY mfa4 ASC, year ASC",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type": "stack",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c",
            "order": "descending"
          },
          "field": "y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "Domestic Material Consumption (tonnes)",
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "format": ".0s",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Material Type",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "Mass (t)",
            "type": "number",
            "format": ".3s"
          },
          {
            "column": "c",
            "property": "Type",
            "type": "string"
          },
          {
            "column": "x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="16db9780-1573-494e-98a9-c203e9115f83"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ### Stand-alone specification
# (eg for use with https://vega.github.io/editor/#/)

# %%
specV3=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/909ad4e2-51d6-4c57-b498-79af37a59bb2?sql=SELECT mfa4, CASE WHEN mfa4='BM' THEN 'Biomass' WHEN mfa4='FF' THEN 'Fossil Fuels' WHEN mfa4='MO' THEN 'Metal Ores' WHEN mfa4='NM' THEN 'Non-Metallic Minerals' END AS c, year AS x, SUM(amount)*1000 as y FROM com_009_flowmfa_autoupdate WHERE flow ILIKE 'DMC' GROUP BY mfa4, year ORDER BY mfa4 ASC, year ASC",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type": "stack",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c",
            "order": "descending"
          },
          "field": "y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "Domestic Material Consumption (tonnes)",
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "format": ".0s",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          },
          "tooltip": {
            "signal": "{'Mass':format(datum.y,'.3s')+'t', 'Type':datum.c, 'Year':datum.x}"
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Material Type",
      "fill": "color",
      "orient": "right"
    }
  ]
}
""")
vega4view=dict(specV3)
Vega(vega4view)
# Out:
# <div class="vega-embed" id="ecf71426-71ab-4614-94ea-8f70b5998bcb"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
