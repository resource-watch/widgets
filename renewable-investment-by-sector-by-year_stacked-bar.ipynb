# %% [markdown]
# ### Data
# ene.025 Renewable Energy Investment by Sector <br>
# https://resourcewatch.carto.com/u/wri-rw/dataset/ene_025_renewable_energy_investment_by_sector <br>

# %%
import numpy as np
import vega
import json
from vega import Vega

# %% [markdown]
# ### Resource Watch specification
# API ID: 118f245b-bf0f-47a0-be1e-3915a3a62cf6 <br>
# https://resourcewatch.org/embed/widget/118f245b-bf0f-47a0-be1e-3915a3a62cf6

# %%
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/37d5db2e-8ab8-4870-bfcc-534cdd5bdb76?sql=SELECT year as x, marine AS a_marine, geothermal AS b_geothermal, small_hydro AS c_small_hydro, biofuels AS d_biofuels, biomass_and_waste_to_energy AS e_biomass, wind AS f_wind, solar AS g_solar FROM ene_025_renewable_energy_investment_by_sector",
      "format": {
        "type": "json",
        "property": "data"
      },
      "transform": [
        {
          "type": "fold",
          "as": [
            "c",
            "y"
          ],
          "fields": [
            "a_marine",
            "b_geothermal",
            "c_small_hydro",
            "d_biofuels",
            "e_biomass",
            "f_wind",
            "g_solar"
          ]
        },
        {
          "type": "stack",
          "field": "y",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c",
            "order": "descending"
          }
        },
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(upper(slice(datum.c,2,3))+slice(datum.c,3),/_/g,' ')"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": false,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "limit": {
              "value": 50
            },
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "New Investment (USD, billions)",
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "name": "bars",
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Sector",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "Investment (USD, billions)",
            "type": "number",
            "format": ".0f"
          },
          {
            "column": "c",
            "property": "Type",
            "type": "string"
          },
          {
            "column": "x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="792cb93e-236d-4612-ba05-8e253644bb94"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ### Stand-alone specification
# (eg for use with https://vega.github.io/editor/#/)

# %%
specV3=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT year as x, marine AS a_marine, geothermal AS b_geothermal, small_hydro AS c_small_hydro, biofuels AS d_biofuels, biomass_and_waste_to_energy AS e_biomass, wind AS f_wind, solar AS g_solar FROM ene_025_renewable_energy_investment_by_sector",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "fold",
          "as": [
            "c",
            "y"
          ],
          "fields": [
            "a_marine",
            "b_geothermal",
            "c_small_hydro",
            "d_biofuels",
            "e_biomass",
            "f_wind",
            "g_solar"
          ]
        },
        {
          "type": "stack",
          "field": "y",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c",
            "order": "descending"
          }
        },
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(upper(slice(datum.c,2,3))+slice(datum.c,3),/_/g,' ')"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": false,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "limit": {
              "value": 50
            },
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "New Investment (USD, billions)",
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "name": "bars",
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          },
          "tooltip": {
            "signal": "{'Investment':'$'+(datum.y)+'B','Sector':datum.c,'Year':datum.x}"
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Sector",
      "fill": "color",
      "orient": "right"
    }
  ]
}
""")
vega4view=dict(specV3)
Vega(vega4view)
# Out:
# <div class="vega-embed" id="674301d4-4553-4c39-85f0-61d6f6aa233b"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
