# %% [markdown]
# ### Data
# soc.026 Gender Gap Index <br>
# https://resourcewatch.carto.com/u/wri-rw/dataset/soc_026_gender_gap_index_1 <br>

# %%
import numpy as np
import vega
import json
from vega import Vega

# %% [markdown]
# ### Resource Watch specification
# API ID: 773eb8e0-3cd8-4b69-ab01-b446bcbd22f7 <br>
# https://resourcewatch.org/embed/widget/773eb8e0-3cd8-4b69-ab01-b446bcbd22f7

# %%
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "config": {
    "axisY": {
      "titleX": -2,
      "titleY": {
        "signal": "height + 10"
      },
      "titleAngle": 0,
      "titleAlign": "right",
      "titleBaseline": "top"
    }
  },
  "data": [
    {
      "transform": [],
      "format": {
        "property": "rows",
        "type": "json"
      },
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT data.rw_country_name, wri.continent, data.economic_participation_and_opportunity_subindex_score AS economic_participation_and_opportunity, data.educational_attainment_subindex_score AS educational_attainment, data.health_and_survival_subindex_score AS health_and_survival, data.political_empowerment_subindex_score AS political_empowerment, data.overall_index_score AS overall FROM soc_026_gender_gap_index_1 data LEFT OUTER JOIN wri_countries_a wri ON data.rw_country_name=wri.name WHERE data.overall_index_score IS NOT NULL ORDER BY wri.continent ASC, data.rw_country_name ASC",
      "name": "ggi"
    },
    {
      "values": [
        "political_empowerment",
        "educational_attainment",
        "health_and_survival",
        "economic_participation_and_opportunity"
      ],
      "name": "fields"
    }
  ],
  "scales": [
    {
      "domain": {
        "field": "data",
        "data": "fields"
      },
      "round": true,
      "range": "width",
      "type": "point",
      "name": "ord"
    },
    {
      "domain": [
        0,
        1
      ],
      "nice": true,
      "zero": true,
      "range": "height",
      "type": "linear",
      "name": "economic_participation_and_opportunity"
    },
    {
      "domain": [
        0,
        1
      ],
      "nice": true,
      "zero": true,
      "range": "height",
      "type": "linear",
      "name": "educational_attainment"
    },
    {
      "domain": [
        0,
        1
      ],
      "nice": true,
      "zero": true,
      "range": "height",
      "type": "linear",
      "name": "health_and_survival"
    },
    {
      "domain": [
        0,
        1
      ],
      "nice": true,
      "zero": true,
      "range": "height",
      "type": "linear",
      "name": "political_empowerment"
    },
    {
      "range": "category",
      "domain": {
        "field": "continent",
        "data": "ggi"
      },
      "type": "ordinal",
      "name": "color"
    }
  ],
  "axes": [
    {
      "offset": {
        "mult": -1,
        "value": "economic_participation_and_opportunity",
        "scale": "ord"
      },
      "title": "Economic",
      "scale": "economic_participation_and_opportunity",
      "zindex": 0,
      "orient": "left",
      "grid": false,
      "labels": true
    },
    {
      "offset": {
        "mult": -1,
        "value": "educational_attainment",
        "scale": "ord"
      },
      "title": "Educational",
      "scale": "educational_attainment",
      "zindex": 0,
      "orient": "left",
      "grid": false,
      "labels": true
    },
    {
      "offset": {
        "mult": -1,
        "value": "health_and_survival",
        "scale": "ord"
      },
      "title": "Health",
      "scale": "health_and_survival",
      "zindex": 0,
      "orient": "left",
      "grid": false,
      "labels": true
    },
    {
      "offset": {
        "mult": -1,
        "value": "political_empowerment",
        "scale": "ord"
      },
      "title": "Political",
      "scale": "political_empowerment",
      "zindex": 0,
      "orient": "left",
      "grid": true,
      "labels": true
    }
  ],
  "marks": [
    {
      "marks": [
        {
          "encode": {
            "enter": {
              "strokeOpacity": {
                "value": 0.9
              },
              "strokeWidth": {
                "value": 1.2
              },
              "stroke": {
                "field": {
                  "parent": "continent"
                },
                "scale": "color"
              },
              "y": {
                "field": {
                  "parent": {
                    "datum": "data"
                  }
                },
                "scale": {
                  "datum": "data"
                }
              },
              "x": {
                "field": "data",
                "scale": "ord"
              }
            }
          },
          "from": {
            "data": "fields"
          },
          "type": "line"
        }
      ],
      "from": {
        "data": "ggi"
      },
      "type": "group"
    }
  ],
  "legends": [
    {
      "orient": "right",
      "fill": "color",
      "title": "Continent"
    }
  ],
  "interaction_config": [
    {
      "config": {
        "fields": [
          {
            "type": "string",
            "column": "rw_country_name",
            "property": "Country"
          },
          {
            "type": "string",
            "column": "continent",
            "property": "Continent"
          }
        ]
      },
      "name": "tooltip"
    }
  ],
  "signals": [
    {
      "on": [
        {
          "update": "datum",
          "events": "@cell:mouseover"
        },
        {
          "update": "null",
          "events": "@cell:mouseout"
        }
      ],
      "value": null,
      "name": "hover"
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="63cd5b87-162e-4596-be56-3eab631e7ecb"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ### Stand-alone specification
# (eg for use with https://vega.github.io/editor/#/)

# %%
specV3=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "config": {
    "axisY": {
      "titleX": -2,
      "titleY": {
        "signal": "height + 10"
      },
      "titleAngle": 0,
      "titleAlign": "right",
      "titleBaseline": "top"
    }
  },
  "data": [
    {
      "transform": [],
      "format": {
        "property": "rows",
        "type": "json"
      },
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT data.rw_country_name, wri.continent, data.economic_participation_and_opportunity_subindex_score AS economic_participation_and_opportunity, data.educational_attainment_subindex_score AS educational_attainment, data.health_and_survival_subindex_score AS health_and_survival, data.political_empowerment_subindex_score AS political_empowerment, data.overall_index_score AS overall FROM soc_026_gender_gap_index_1 data LEFT OUTER JOIN wri_countries_a wri ON data.rw_country_name=wri.name WHERE data.overall_index_score IS NOT NULL ORDER BY wri.continent ASC, data.rw_country_name ASC",
      "name": "ggi"
    },
    {
      "values": [
        "political_empowerment",
        "educational_attainment",
        "health_and_survival",
        "economic_participation_and_opportunity"
      ],
      "name": "fields"
    }
  ],
  "scales": [
    {
      "domain": {
        "field": "data",
        "data": "fields"
      },
      "round": true,
      "range": "width",
      "type": "point",
      "name": "ord"
    },
    {
      "domain": [
        0,
        1
      ],
      "nice": true,
      "zero": true,
      "range": "height",
      "type": "linear",
      "name": "economic_participation_and_opportunity"
    },
    {
      "domain": [
        0,
        1
      ],
      "nice": true,
      "zero": true,
      "range": "height",
      "type": "linear",
      "name": "educational_attainment"
    },
    {
      "domain": [
        0,
        1
      ],
      "nice": true,
      "zero": true,
      "range": "height",
      "type": "linear",
      "name": "health_and_survival"
    },
    {
      "domain": [
        0,
        1
      ],
      "nice": true,
      "zero": true,
      "range": "height",
      "type": "linear",
      "name": "political_empowerment"
    },
    {
      "range": "category",
      "domain": {
        "field": "continent",
        "data": "ggi"
      },
      "type": "ordinal",
      "name": "color"
    }
  ],
  "axes": [
    {
      "offset": {
        "mult": -1,
        "value": "economic_participation_and_opportunity",
        "scale": "ord"
      },
      "title": "Economic",
      "scale": "economic_participation_and_opportunity",
      "zindex": 0,
      "orient": "left",
      "grid": false,
      "labels": true
    },
    {
      "offset": {
        "mult": -1,
        "value": "educational_attainment",
        "scale": "ord"
      },
      "title": "Educational",
      "scale": "educational_attainment",
      "zindex": 0,
      "orient": "left",
      "grid": false,
      "labels": true
    },
    {
      "offset": {
        "mult": -1,
        "value": "health_and_survival",
        "scale": "ord"
      },
      "title": "Health",
      "scale": "health_and_survival",
      "zindex": 0,
      "orient": "left",
      "grid": false,
      "labels": true
    },
    {
      "offset": {
        "mult": -1,
        "value": "political_empowerment",
        "scale": "ord"
      },
      "title": "Political",
      "scale": "political_empowerment",
      "zindex": 0,
      "orient": "left",
      "grid": true,
      "labels": true
    }
  ],
  "marks": [
    {
      "marks": [
        {
          "encode": {
            "enter": {
              "strokeOpacity": {
                "value": 0.9
              },
              "strokeWidth": {
                "value": 1.2
              },
              "stroke": {
                "field": {
                  "parent": "continent"
                },
                "scale": "color"
              },
              "y": {
                "field": {
                  "parent": {
                    "datum": "data"
                  }
                },
                "scale": {
                  "datum": "data"
                }
              },
              "x": {
                "field": "data",
                "scale": "ord"
              }
            }
          },
          "from": {
            "data": "fields"
          },
          "type": "line"
        }
      ],
      "from": {
        "data": "ggi"
      },
      "type": "group"
    }
  ],
  "legends": [
    {
      "orient": "right",
      "fill": "color",
      "title": "Continent"
    }
  ],
  "interaction_config": [
    {
      "config": {
        "fields": [
          {
            "type": "string",
            "column": "rw_country_name",
            "property": "Country"
          },
          {
            "type": "string",
            "column": "continent",
            "property": "Continent"
          }
        ]
      },
      "name": "tooltip"
    }
  ],
  "signals": [
    {
      "on": [
        {
          "update": "datum",
          "events": "@cell:mouseover"
        },
        {
          "update": "null",
          "events": "@cell:mouseout"
        }
      ],
      "value": null,
      "name": "hover"
    }
  ]
}
""")
vega4view=dict(specV3)
Vega(vega4view)
# Out:
# <div class="vega-embed" id="abdda4b1-8336-4fd8-aa9f-7d4575c96c5e"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
