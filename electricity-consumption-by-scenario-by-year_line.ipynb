# %% [markdown]
# ### Data
# ene.026 GCAM Projections <br>
# https://resourcewatch.carto.com/u/wri-rw/dataset/dash_0061_gcam_dashboard_series (pre-processed data)<br>

# %%
import numpy as np
import vega
import json
from vega import Vega

# %% [markdown]
# ### Resource Watch specification
# API ID: a6d0a52c-8f17-439b-a5a1-f1d1b1d6b003 <br>
# https://resourcewatch.org/embed/widget/a6d0a52c-8f17-439b-a5a1-f1d1b1d6b003

# %%
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "table",
      "url": "https://api.resourcewatch.org/v1/query/2e0e735c-7bd9-44f4-ac5f-fbc8a967da8a?sql=SELECT year as x, value as y, scenario as c FROM dash_0061_gcam_dashboard_series WHERE  indicator = 'Secondary Energy|Electricity' ORDER BY scenario ASC, year ASC",
      "format": {
        "property": "data",
        "type": "json"
      },
      "transform": [
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(datum.c,/_/g,' ')"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x && hover.datum.y === datum.y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "point",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": [
        "Paris - Increased Ambition",
        "Paris - Continued Ambition",
        "Reference - Low Policy",
        "Reference - No Policy"
      ]
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "labelOverlap": "parity",
      "scale": "x"
    },
    {
      "title": "Global Electricity Consumption (exajoules)",
      "orient": "left",
      "labelOverlap": "parity",
      "scale": "y"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "type": "group",
      "from": {
        "facet": {
          "name": "series",
          "data": "table",
          "groupby": "c"
        }
      },
      "marks": [
        {
          "type": "line",
          "interactive": false,
          "from": {
            "data": "series"
          },
          "encode": {
            "enter": {
              "x": {
                "scale": "x",
                "field": "x"
              },
              "y": {
                "scale": "y",
                "field": "y"
              },
              "stroke": {
                "scale": "color",
                "field": "c"
              },
              "strokeWidth": {
                "value": 2
              }
            }
          }
        }
      ]
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "fill": {
            "scale": "color",
            "field": "c"
          },
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Climate Scenario",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "datum.y",
            "property": "Electricity Consumption (exajoules)",
            "type": "number",
            "format": ".0f"
          },
          {
            "column": "datum.c",
            "property": "Scenario",
            "type": "string"
          },
          {
            "column": "datum.x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="4515daa5-69b5-441e-b51b-b0eeba9a3347"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ### Stand-alone specification
# (eg for use with https://vega.github.io/editor/#/)

# %%
specV3=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "events": "@cell:mouseover",
          "update": "datum"
        },
        {
          "events": "@cell:mouseout",
          "update": "null"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "table",
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT year as x, value as y, scenario as c FROM dash_0061_gcam_dashboard_series WHERE  indicator = 'Secondary Energy|Electricity' ORDER BY scenario ASC, year ASC",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(datum.c,/_/g,' ')"
        }
      ]
    },
    {
      "name": "dots",
      "source": "table",
      "transform": [
        {
          "type": "filter",
          "expr": "hover && hover.datum.x === datum.x && hover.datum.y === datum.y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "point",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": [
        "Paris - Increased Ambition",
        "Paris - Continued Ambition",
        "Reference - Low Policy",
        "Reference - No Policy"
      ]
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "labelOverlap": "parity",
      "scale": "x",
      "domainColor": "black",
      "zindex": 1
    },
    {
      "title": "Global Electricity Consumption (exajoules)",
      "orient": "left",
      "labelOverlap": "parity",
      "scale": "y",
      "grid": true,
      "zindex": 0
    }
  ],
  "marks": [
    {
      "name": "lines",
      "type": "group",
      "from": {
        "facet": {
          "name": "series",
          "data": "table",
          "groupby": "c"
        }
      },
      "marks": [
        {
          "type": "line",
          "interactive": false,
          "from": {
            "data": "series"
          },
          "encode": {
            "enter": {
              "x": {
                "scale": "x",
                "field": "x"
              },
              "y": {
                "scale": "y",
                "field": "y"
              },
              "stroke": {
                "scale": "color",
                "field": "c"
              },
              "strokeWidth": {
                "value": 2
              }
            }
          }
        }
      ]
    },
    {
      "name": "pointss",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          },
          "opacity": {
            "value": 0
          }
        }
      }
    },
    {
      "name": "points",
      "interactive": false,
      "type": "symbol",
      "from": {
        "data": "dots"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "y": {
            "scale": "y",
            "field": "y"
          }
        },
        "update": {
          "fill": {
            "scale": "color",
            "field": "c"
          },
          "opacity": {
            "value": 1
          }
        }
      }
    },
    {
      "name": "cell",
      "type": "path",
      "from": {
        "data": "pointss"
      },
      "transform": [
        {
          "type": "voronoi",
          "x": "datum.x",
          "y": "datum.y",
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ]
        }
      ],
      "encode": {
        "update": {
          "fill": {
            "value": "red"
          },
          "path": {
            "field": "path"
          },
          "opacity": {
            "value": 0
          }
        },
        "hover": {
          "tooltip": {
            "signal": "{'Consumption':round(hover.datum.y)+' EJ','Scenario':hover.datum.c,'Year':hover.datum.x}"
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Climate Scenario",
      "fill": "color",
      "orient": "right"
    }
  ]
}

""")
vega4view=dict(specV3)
Vega(vega4view)
# Out:
# <div class="vega-embed" id="49a6282e-ea65-4b95-a77d-6f93e4e90a57"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
