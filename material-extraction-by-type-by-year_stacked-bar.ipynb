# %% [markdown]
# ### Data
# com.009 Material Extraction, Trade, and Use 3 <br>
# https://resourcewatch.carto.com/u/wri-rw/dataset/com_009_flowmfa_autoupdate <br>

# %%
import numpy as np
import vega
import json
from vega import Vega

# %% [markdown]
# ### Resource Watch specification
# API ID: 36ed305a-1049-4431-834c-eff40213808a <br>
# https://resourcewatch.org/embed/widget/36ed305a-1049-4431-834c-eff40213808a

# %%
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT year AS x, mfa4, CASE WHEN mfa4='BM' THEN 'Biomass' WHEN mfa4='FF' THEN 'Fossil Fuels' WHEN mfa4='MO' THEN 'Metal Ores' WHEN mfa4='NM' THEN 'Non-Metallic Minerals' END AS c, (sum(amount)*1000) AS y FROM com_009_flowmfa_autoupdate WHERE flow='DE' GROUP BY x, mfa4 ORDER BY x ASC, mfa4 DESC",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "stack",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c"
          },
          "field": "y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "Extracted Material (tonnes)",
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "format": ".0s",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Material Type",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "Mass (t)",
            "type": "number",
            "format": ".3s"
          },
          {
            "column": "c",
            "property": "Type",
            "type": "string"
          },
          {
            "column": "x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="7803fcda-eea5-4172-9f38-2c5ae1e43ae8"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ### Stand-alone specification
# (eg for use with https://vega.github.io/editor/#/)

# %%
specV3=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT year AS x, mfa4, CASE WHEN mfa4='BM' THEN 'Biomass' WHEN mfa4='FF' THEN 'Fossil Fuels' WHEN mfa4='MO' THEN 'Metal Ores' WHEN mfa4='NM' THEN 'Non-Metallic Minerals' END AS c, (sum(amount)*1000) AS y FROM com_009_flowmfa_autoupdate WHERE flow='DE' GROUP BY x, mfa4 ORDER BY x ASC, mfa4 DESC",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "stack",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c"
          },
          "field": "y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "Extracted Material (tonnes)",
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "format": ".0s",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          },
          "tooltip": {
            "signal": "{'Mass': format(datum.y,'.3s') + ' t','Type':datum.c, 'Year':datum.x}"
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Material Type",
      "fill": "color",
      "orient": "right"
    }
  ]
}
""")
vega4view=dict(specV3)
Vega(vega4view)
# Out:
# <div class="vega-embed" id="e4b20704-c514-4a0b-95ea-923d9c982aa2"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
