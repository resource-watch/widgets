# %% [markdown]
# ### Data
# com.009 Material Extraction, Trade, and Use 3 <br>
# https://resourcewatch.carto.com/u/wri-rw/dataset/com_009_flowmfa_autoupdate <br>

# %%
import numpy as np
import vega
import json
from vega import Vega

# %% [markdown]
# ### Resource Watch specification
# API ID: 142c1d38-be73-40ad-822c-6f74d0d4bfb1 <br>
# https://resourcewatch.org/embed/widget/142c1d38-be73-40ad-822c-6f74d0d4bfb1

# %%
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "config": {
    "range": {
      "category20": [
        "#5079a5",
        "#ef8e3b",
        "#dd565c",
        "#79b7b2",
        "#5da052",
        "#ecc853",
        "#ad7aa1",
        "#ef9ba7",
        "#9b7461",
        "#bab0ac"
      ],
      "ordinal": {
        "scheme": "greens"
      },
      "ramp": {
        "scheme": "purples"
      }
    }
  },
  "data": [
    {
      "name": "table",
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT data.year AS x, regions.v2 AS c, SUM(data.amount)*1000 AS y FROM com_009_flowmfa_autoupdate data LEFT OUTER JOIN com_009_country countries ON data.isoalpha3=countries.isoalpha3 LEFT OUTER JOIN com_009_regions regions ON countries.region=regions.v1 WHERE flow='DE' GROUP BY data.year, regions.v2 ORDER BY x ASC, c ASC",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "stack",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c",
            "order": "descending"
          },
          "field": "y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category20",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "labelOverlap": "greedy",
      "encode": {
        "labels": {
          "update": {
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "Extracted Material (tonnes)",
      "orient": "left",
      "scale": "y",
      "format": ".0s",
      "zindex": 0,
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Region",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "Mass (t)",
            "type": "number",
            "format": ".3s"
          },
          {
            "column": "c",
            "property": "Region",
            "type": "string"
          },
          {
            "column": "x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="c037f7c1-ef02-40d1-89cd-581739a4a0d8"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ### Stand-alone specification
# (eg for use with https://vega.github.io/editor/#/)

# %%
specV3=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "config": {
    "range": {
      "category20": [
        "#5079a5",
        "#ef8e3b",
        "#dd565c",
        "#79b7b2",
        "#5da052",
        "#ecc853",
        "#ad7aa1",
        "#ef9ba7",
        "#9b7461",
        "#bab0ac"
      ],
      "ordinal": {
        "scheme": "greens"
      },
      "ramp": {
        "scheme": "purples"
      }
    }
  },
  "data": [
    {
      "name": "table",
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT data.year AS x, regions.v2 AS c, SUM(data.amount)*1000 AS y FROM com_009_flowmfa_autoupdate data LEFT OUTER JOIN com_009_country countries ON data.isoalpha3=countries.isoalpha3 LEFT OUTER JOIN com_009_regions regions ON countries.region=regions.v1 WHERE flow='DE' GROUP BY data.year, regions.v2 ORDER BY x ASC, c ASC",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "stack",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c",
            "order": "descending"
          },
          "field": "y"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category20",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "labelOverlap": "greedy",
      "encode": {
        "labels": {
          "update": {
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "Extracted Material (tonnes)",
      "orient": "left",
      "scale": "y",
      "format": ".0s",
      "zindex": 0,
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          },
          "tooltip": {
            "signal": "{'Mass': format(datum.y,'.3s') + ' t','Region':datum.c, 'Year':datum.x}"
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Region",
      "fill": "color",
      "orient": "right"
    }
  ]
}
""")
vega4view=dict(specV3)
Vega(vega4view)
# Out:
# <div class="vega-embed" id="8772eed2-f52e-4019-8d4e-74180b45ebb6"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
